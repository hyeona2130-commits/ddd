# %%
# !wandb login
# Out:
# wandb: Logging into https://api.wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: Find your API key here: https://wandb.ai/authorize?ref=models
# wandb: Paste an API key from your profile and hit enter:
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: hyeona2130 (hyeona2130-) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#문제 1-1 실행화면
# %cd /content/drive/MyDrive/ddd
# !python _01_code/_18_lstm_and_its_application/g_crypto_currency_regression_train_lstm.py --wandb --epochs 300
# Out:
# /content/drive/MyDrive/ddd
# wandb: Currently logged in as: hyeona2130 (hyeona2130-) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ Waiting for wandb.init()...
# wandb: ⣾ setting up run uv06uvt7 (0.2s)
# wandb: ⣷ setting up run uv06uvt7 (0.2s)
# wandb: Tracking run with wandb version 0.23.1
# wandb: Run data is saved locally in /content/drive/MyDrive/ddd/wandb/run-20251219_114209-uv06uvt7
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run 2025-12-19_11-42-08
# wandb: ⭐️ View project at https://wandb.ai/hyeona2130-/lstm_regression_btc_krw
# wandb: 🚀 View run at https://wandb.ai/hyeona2130-/lstm_regression_btc_krw/runs/uv06uvt7
# Namespace(wandb=True, batch_size=2048, epochs=300, learning_rate=0.0001, weight_decay=0.0, validation_intervals=30, early_stop_patience=30, early_stop_delta=1e-06)
# ...

# %%
#문제 1-2 실행화면
# %cd /content/drive/MyDrive/ddd
# !python _01_code/_18_lstm_and_its_application/h_crypto_currency_regression_test_lstm.py --wandb --epochs 300
# Out:
# /content/drive/MyDrive/ddd
# MODEL FILE: /content/drive/MyDrive/ddd/_01_code/_18_lstm_and_its_application/checkpoints/lstm_regression_btc_krw_checkpoint_latest.pt
# CSV PATH: /content/drive/MyDrive/ddd/_00_data/k_cryptocurrency/BTC_KRW.csv
# DF COLUMNS (after drop Date): ['Open', 'High', 'Low', 'Close', 'Volume'] target_idx: 3
# [TEST DATA]
#  0: 1,132.76 <--> 1,275.74 (Loss:        142.98)
#  1: 1,131.47 <--> 1,280.50 (Loss:        149.03)
#  2: 1,132.44 <--> 1,250.72 (Loss:        118.28)
#  3: 1,131.17 <--> 1,332.08 (Loss:        200.90)
#  4: 1,131.75 <--> 1,302.83 (Loss:        171.08)
#  5: 1,130.98 <--> 1,334.95 (Loss:        203.97)
#  6: 1,131.89 <--> 1,275.71 (Loss:        143.82)
#  7: 1,132.15 <--> 1,244.11 (Loss:        111.95)
#  8: 1,130.90 <--> 1,334.35 (Loss:        203.45)
#  9: 1,130.78 <--> 1,333.17 (Loss:        202.39)
# CSV PATH: /content/drive/MyDrive/ddd/_00_data/k_cryptocurrency/BTC_KRW.csv
# ...

# %%
#문제 1-3 실행화면
# %cd /content/drive/MyDrive/ddd
# !python _01_code/_18_lstm_and_its_application/i_crypto_currency_classification_train_lstm.py --wandb --epochs 300
# Out:
# /content/drive/MyDrive/ddd
# wandb: Currently logged in as: hyeona2130 (hyeona2130-) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ Waiting for wandb.init()...
# wandb: Tracking run with wandb version 0.23.1
# wandb: Run data is saved locally in /content/drive/MyDrive/ddd/wandb/run-20251219_114743-hyrs14tg
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run 2025-12-19_11-47-43
# wandb: ⭐️ View project at https://wandb.ai/hyeona2130-/lstm_classification_btc_krw
# wandb: 🚀 View run at https://wandb.ai/hyeona2130-/lstm_classification_btc_krw/runs/hyrs14tg
# Namespace(wandb=True, batch_size=2048, epochs=300, learning_rate=0.0001, weight_decay=0.0, validation_intervals=30, early_stop_patience=30, early_stop_delta=1e-06)
# ...

# %%
#문제 1-4 실행화면
# %cd /content/drive/MyDrive/ddd
# !python _01_code/_18_lstm_and_its_application/j_crypto_currency_classification_test_lstm.py --wandb --epochs 300
# Out:
# /content/drive/MyDrive/ddd
# MODEL FILE: /content/drive/MyDrive/ddd/_01_code/_18_lstm_and_its_application/checkpoints/lstm_classification_btc_krw_checkpoint_latest.pt
# CSV PATH: /content/drive/MyDrive/ddd/_00_data/k_cryptocurrency/BTC_KRW.csv
# DF COLUMNS (after drop Date): ['Open', 'High', 'Low', 'Close', 'Volume'] target_idx: 3
# [TEST DATA]
# TEST RESULTS: 60.000%
#  0:   0.00 <-->   1.00
#  1:   0.00 <-->   0.00
#  2:   0.00 <-->   1.00
#  3:   0.00 <-->   0.00
#  4:   0.00 <-->   0.00
#  5:   0.00 <-->   0.00
#  6:   0.00 <-->   1.00
#  7:   0.00 <-->   0.00
#  8:   0.00 <-->   1.00
#  9:   0.00 <-->   0.00

# %%
#문제 2-1 실행화면
# num_layers=3,dropout=0.2, LSTM 뒤 Linear layer 개수=2 추가 설정
# %cd /content/drive/MyDrive/ddd
# !python _01_code/_18_lstm_and_its_application/g_crypto_currency_regression_train_lstm.py --wandb --epochs 300
# Out:
# /content/drive/MyDrive/ddd
# wandb: Currently logged in as: hyeona2130 (hyeona2130-) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ Waiting for wandb.init()...
# wandb: Tracking run with wandb version 0.23.1
# wandb: Run data is saved locally in /content/drive/MyDrive/ddd/wandb/run-20251219_120911-kpr5crwi
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run 2025-12-19_12-09-11
# wandb: ⭐️ View project at https://wandb.ai/hyeona2130-/lstm_regression_btc_krw
# wandb: 🚀 View run at https://wandb.ai/hyeona2130-/lstm_regression_btc_krw/runs/kpr5crwi
# Namespace(wandb=True, batch_size=2048, epochs=300, learning_rate=0.0001, weight_decay=0.0, validation_intervals=30, early_stop_patience=30, early_stop_delta=1e-06)
# ...

# %%
# %cd /content/drive/MyDrive/ddd
# !python _01_code/_18_lstm_and_its_application/h_crypto_currency_regression_test_lstm.py --wandb
# Out:
# /content/drive/MyDrive/ddd
# MODEL FILE: /content/drive/MyDrive/ddd/_01_code/_18_lstm_and_its_application/checkpoints/lstm_regression_btc_krw_checkpoint_latest.pt
# CSV PATH: /content/drive/MyDrive/ddd/_00_data/k_cryptocurrency/BTC_KRW.csv
# DF COLUMNS (after drop Date): ['Open', 'High', 'Low', 'Close', 'Volume'] target_idx: 3
# [TEST DATA]
#  0: 1,402.78 <--> 1,244.11 (Loss:        158.68)
#  1: 1,383.83 <--> 1,334.35 (Loss:         49.48)
#  2: 1,400.71 <--> 1,302.83 (Loss:         97.89)
#  3: 1,399.48 <--> 1,280.50 (Loss:        118.97)
#  4: 1,396.80 <--> 1,332.08 (Loss:         64.72)
#  5: 1,391.33 <--> 1,334.95 (Loss:         56.37)
#  6: 1,403.71 <--> 1,250.72 (Loss:        152.99)
#  7: 1,404.34 <--> 1,275.74 (Loss:        128.61)
#  8: 1,376.84 <--> 1,333.17 (Loss:         43.67)
#  9: 1,401.56 <--> 1,275.71 (Loss:        125.85)
# CSV PATH: /content/drive/MyDrive/ddd/_00_data/k_cryptocurrency/BTC_KRW.csv
# ...

# %%
#문제 2-2 실행화면
# %cd /content/drive/MyDrive/ddd
# !python _01_code/_18_lstm_and_its_application/i_crypto_currency_classification_train_lstm.py --wandb --epochs 300
# Out:
# /content/drive/MyDrive/ddd
# wandb: Currently logged in as: hyeona2130 (hyeona2130-) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ Waiting for wandb.init()...
# wandb: Tracking run with wandb version 0.23.1
# wandb: Run data is saved locally in /content/drive/MyDrive/ddd/wandb/run-20251219_121001-e9n1rr1r
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run 2025-12-19_12-10-01
# wandb: ⭐️ View project at https://wandb.ai/hyeona2130-/lstm_classification_btc_krw
# wandb: 🚀 View run at https://wandb.ai/hyeona2130-/lstm_classification_btc_krw/runs/e9n1rr1r
# Namespace(wandb=True, batch_size=2048, epochs=300, learning_rate=0.0001, weight_decay=0.0, validation_intervals=30, early_stop_patience=30, early_stop_delta=1e-06)
# ...

# %%
# %cd /content/drive/MyDrive/ddd
# !python _01_code/_18_lstm_and_its_application/j_crypto_currency_classification_test_lstm.py --wandb
# Out:
# /content/drive/MyDrive/ddd
# MODEL FILE: /content/drive/MyDrive/ddd/_01_code/_18_lstm_and_its_application/checkpoints/lstm_classification_btc_krw_checkpoint_latest.pt
# CSV PATH: /content/drive/MyDrive/ddd/_00_data/k_cryptocurrency/BTC_KRW.csv
# DF COLUMNS (after drop Date): ['Open', 'High', 'Low', 'Close', 'Volume'] target_idx: 3
# [TEST DATA]
# TEST RESULTS: 40.000%
#  0:   1.00 <-->   0.00
#  1:   1.00 <-->   0.00
#  2:   1.00 <-->   0.00
#  3:   1.00 <-->   1.00
#  4:   1.00 <-->   0.00
#  5:   1.00 <-->   1.00
#  6:   1.00 <-->   0.00
#  7:   1.00 <-->   1.00
#  8:   1.00 <-->   0.00
#  9:   1.00 <-->   1.00

# %%
#문제 3-1 실행화면
# 'Next_open' 행 추가 /  n_input=6 으로 수정
# %cd /content/drive/MyDrive/ddd
# !python _01_code/_18_lstm_and_its_application/g_crypto_currency_regression_train_lstm.py --wandb --epochs 300
# Out:
# /content/drive/MyDrive/ddd
# wandb: Currently logged in as: hyeona2130 (hyeona2130-) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ setting up run 5nhg05sv (0.2s)
# wandb: Tracking run with wandb version 0.23.1
# wandb: Run data is saved locally in /content/drive/MyDrive/ddd/wandb/run-20251219_122022-5nhg05sv
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run 2025-12-19_12-20-22
# wandb: ⭐️ View project at https://wandb.ai/hyeona2130-/lstm_regression_btc_krw
# wandb: 🚀 View run at https://wandb.ai/hyeona2130-/lstm_regression_btc_krw/runs/5nhg05sv
# Namespace(wandb=True, batch_size=2048, epochs=300, learning_rate=0.0001, weight_decay=0.0, validation_intervals=30, early_stop_patience=30, early_stop_delta=1e-06)
# {'epochs': 300, 'batch_size': 2048, 'validation_intervals': 30, 'learning_rate': 0.0001, 'early_stop_patience': 30, 'early_stop_delta': 1e-06, 'weight_decay': 0}
# ...

# %%
# %cd /content/drive/MyDrive/ddd
# !python _01_code/_18_lstm_and_its_application/h_crypto_currency_regression_test_lstm.py --wandb
# Out:
# /content/drive/MyDrive/ddd
# MODEL FILE: /content/drive/MyDrive/ddd/_01_code/_18_lstm_and_its_application/checkpoints/lstm_regression_btc_krw_checkpoint_latest.pt
# CSV PATH: /content/drive/MyDrive/ddd/_00_data/k_cryptocurrency/BTC_KRW.csv
# DF COLUMNS (after drop Date): ['Open', 'High', 'Low', 'Close', 'Volume'] target_idx: 3
# [TEST DATA]
#  0: 1,418.51 <--> 1,275.71 (Loss:        142.80)
#  1: 1,421.68 <--> 1,244.11 (Loss:        177.57)
#  2: 1,425.87 <--> 1,275.74 (Loss:        150.13)
#  3: 1,424.30 <--> 1,250.72 (Loss:        173.58)
#  4: 1,408.79 <--> 1,280.50 (Loss:        128.29)
#  5: 1,395.44 <--> 1,332.08 (Loss:         63.36)
#  6: 1,415.91 <--> 1,302.83 (Loss:        113.08)
#  7: 1,377.55 <--> 1,334.95 (Loss:         42.59)
#  8: 1,355.51 <--> 1,333.17 (Loss:         22.34)
#  9: 1,362.52 <--> 1,334.35 (Loss:         28.17)
# CSV PATH: /content/drive/MyDrive/ddd/_00_data/k_cryptocurrency/BTC_KRW.csv
# ...

# %%
#문제 3-2 실행화면
# %cd /content/drive/MyDrive/ddd

# !python _01_code/_18_lstm_and_its_application/i_crypto_currency_classification_train_lstm.py --wandb --epochs 300
# Out:
# /content/drive/MyDrive/ddd
# wandb: Currently logged in as: hyeona2130 (hyeona2130-) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ Waiting for wandb.init()...
# wandb: Tracking run with wandb version 0.23.1
# wandb: Run data is saved locally in /content/drive/MyDrive/ddd/wandb/run-20251219_131519-lr0rh7o8
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run 2025-12-19_13-15-19
# wandb: ⭐️ View project at https://wandb.ai/hyeona2130-/lstm_classification_btc_krw
# wandb: 🚀 View run at https://wandb.ai/hyeona2130-/lstm_classification_btc_krw/runs/lr0rh7o8
# Namespace(wandb=True, batch_size=2048, epochs=300, learning_rate=0.0001, weight_decay=0.0, validation_intervals=30, early_stop_patience=30, early_stop_delta=1e-06)
# ...

# %%
# %cd /content/drive/MyDrive/ddd
# !python _01_code/_18_lstm_and_its_application/j_crypto_currency_classification_test_lstm.py --wandb
# Out:
# /content/drive/MyDrive/ddd
# MODEL FILE: /content/drive/MyDrive/ddd/_01_code/_18_lstm_and_its_application/checkpoints/lstm_classification_btc_krw_checkpoint_latest.pt
# CSV PATH: /content/drive/MyDrive/ddd/_00_data/k_cryptocurrency/BTC_KRW.csv
# DF COLUMNS (after drop Date): ['Open', 'High', 'Low', 'Close', 'Volume', 'Next_Open'] target_idx: 3
# [TEST DATA]
# TEST RESULTS: 80.000%
#  0:   1.00 <-->   1.00
#  1:   0.00 <-->   0.00
#  2:   1.00 <-->   0.00
#  3:   0.00 <-->   0.00
#  4:   0.00 <-->   0.00
#  5:   1.00 <-->   1.00
#  6:   1.00 <-->   1.00
#  7:   1.00 <-->   1.00
#  8:   1.00 <-->   0.00
#  9:   0.00 <-->   0.00

# %%
#숙제후기
'''
이번 과제를 통해 LSTM 기반 시계열 모델을 실제 금융 데이터에 적용하며, 데이터 전처리부터 모델 구조 설계, 하이퍼파라미터 튜닝까지 전체 학습 파이프라인을 경험할 수 있었다.
특히 입력 feature 수 변화(Next_Open 추가)에 따라 데이터 로더와 모델 구조를 일관되게 맞추는 것이 모델 학습과 추론의 안정성에 매우 중요하다는 점을 이해하게 되었다.
또한 LSTM layer 수, Linear layer 구성, dropout, weight decay 등의 설정이 성능에 미치는 영향을 실험적으로 비교하며 모델 일반화의 의미를 체감할 수 있었다.
'''
